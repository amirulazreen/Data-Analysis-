# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

mobiles = pd.read_csv(r"C:\Users\2600\Desktop\K-Youth\Python\Homework\mobiles.csv") #Import datafile 
mobiles.head(3)
# Out:
#    Unnamed: 0    Brand                                           Title  \
# 0           0    APPLE                  APPLE iPhone 13 (Pink, 128 GB)
# 1           1     POCO                   POCO C51 (Power Black, 64 GB)
# 2           2  OnePlus  OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)
#
#           Model Name Model Number  Price  Rating  No_of_Ratings  \
# 0          iPhone 13    MLPH3HN/A  52499     4.7       259109.0
# 1                C51    MZB0E6DIN   6499     4.1        78642.0
# 2  Nord CE 2 Lite 5G  CPH2381/CVD  17196     4.4       110949.0
#
#    No_of_Reviews                                         In The Box  ...  \
# 0        12745.0    iPhone, USB-C to Lightning Cable, Documentation  ...
# 1         4449.0  Handset, 10W Adapter, USB Cable, Sim Eject Too...  ...
# 2         7728.0  Phone,SIM Tray Ejector, Adapter, Phone Case, U...  ...
#
#                                              Sensors        Browser  \
# 0  Face ID, Barometer, Three‑axis Gyro, Accelerom...         Safari
# 1                  Accelerometer, Fingerprint Sensor  Google Chrome
# 2                  Accelerometer, Fingerprint Sensor  Google Chrome
#
#                                       Other Features  \
# 0  Splash, Water and Dust Resistant IP68 Rated (M...
# 1  Splash Resistant Coating, MIUI Dialer, Upto 3 ...
# 2  Splash Resistant Coating, MIUI Dialer, Upto 3 ...
#
#                                           GPS Type  \
# 0  Built-in GPS, GLONASS, Galileo, QZSS and BeiDou
# 1                       GPS, AGPS, GLONASS, BEIDOU
# 2                       GPS, AGPS, GLONASS, BEIDOU
#
#                                        Video Formats Battery Capacity  \
# 0  HEVC, H.264, MPEG‑4 Part 2 and Motion JPEG, HD...         3240 mAh
# 1                                                NaN         5000 mAh
# 2                                                NaN         5000 mAh
#
#       Width    Height    Depth  Weight
# 0   71.5 mm  146.7 mm  7.65 mm   173 g
# 1  76.75 mm  164.9 mm  9.09 mm   192 g
# 2  76.75 mm  164.9 mm  9.09 mm   192 g
#
# [3 rows x 74 columns]

# %%
mobiles.shape #To get understanding on how big the data is
# Out:
# (984, 74)

# %%
mobiles.columns #checking which columns can be useful for comparison
# Out:
# Index(['Unnamed: 0', 'Brand', 'Title', 'Model Name', 'Model Number', 'Price',
#        'Rating', 'No_of_Ratings', 'No_of_Reviews', 'In The Box', 'Color',
#        'Browse Type', 'SIM Type', 'Hybrid Sim Slot', 'Touchscreen',
#        'OTG Compatible', 'Quick Charging', 'Sound Enhancements',
#        'Display_size_cm', 'Display_size_inches', 'Resolution',
#        'Resolution Type', 'Display Type', 'Other Display Features',
#        'Operating System', 'Processor Type', 'Processor Core',
#        'Operating Frequency', 'Internal Storage', 'Primary Camera Available',
#        'Primary Camera', 'Primary Camera Features',
#        'Secondary Camera Available', 'Secondary Camera',
#        'Secondary Camera Features', 'Flash', 'HD Recording',
#        'Full HD Recording', 'Video Recording', 'Video Recording Resolution',
#        'Digital Zoom', 'Frame Rate', 'Dual Camera Lens', 'Call Wait/Hold',
#        'Network Type', 'Supported Networks', 'Internet Connectivity', '3G',
#        'Pre-installed Browser', 'Bluetooth Support', 'Bluetooth Version',
#        'Wi-Fi', 'Wi-Fi Version', 'Wi-Fi Hotspot', 'NFC', 'EDGE', 'Map Support',
#        'GPS Support', 'Smartphone', 'SIM Size', 'Mobile Tracker',
#        'Removable Battery', 'SMS', 'Graphics PPI', 'Sensors', 'Browser',
#        'Other Features', 'GPS Type', 'Video Formats', 'Battery Capacity',
#        'Width', 'Height', 'Depth', 'Weight'],
#       dtype='object')

# %%
mobiles.isna().mean().sort_values(ascending=False) #To find the % of missing value for every column
# Out:
# Mobile Tracker           0.907520
# EDGE                     0.821138
# Pre-installed Browser    0.776423
# Sound Enhancements       0.750000
# 3G                       0.645325
#                            ...
# Browse Type              0.000000
# Display_size_cm          0.000000
# Display_size_inches      0.000000
# Brand                    0.000000
# Unnamed: 0               0.000000
# Length: 74, dtype: float64

# %%
over_80 = [] #Columns with missing detail above 80%
under_80 = [] #Columns with missing detail under 80%
missing = mobiles.isna().mean().sort_values(ascending=False)
for i in missing : 
    if i > 0.80 :
        over_80.append(i)
    elif i <= 80 and i>0 :
        under_80.append(i)
over_80
# Out:
# [0.907520325203252, 0.8211382113821138]

# %%
mobiles.fillna('No Detail',inplace=True) #Fill the missing detail with 'No detail'

# %%
Columns_to_drop = ['Mobile Tracker','EDGE'] #Drop columns with missing detail above 80%
mobiles.drop(columns=Columns_to_drop)
# Out:
#      Unnamed: 0    Brand                                              Title  \
# 0             0    APPLE                     APPLE iPhone 13 (Pink, 128 GB)
# 1             1     POCO                      POCO C51 (Power Black, 64 GB)
# 2             2  OnePlus     OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)
# 3             3   realme                realme 11x 5G (Purple Dawn, 128 GB)
# 4             4   realme             realme 11x 5G (Midnight Black, 128 GB)
# ..          ...      ...                                                ...
# 979         979    APPLE                    APPLE iPhone 12 (White, 128 GB)
# 980         980    Tecno                 Tecno Pova 3 (Tech Silver, 128 GB)
# 981         981    REDMI           REDMI Note 11 SE (Thunder Purple, 64 GB)
# 982         982     vivo                    vivo Y16 (Steller Black, 64 GB)
# 983         983    Tecno  Tecno Camon 19 Pro Multi-Colour Changing Back-...
#
#                                         Model Name   Model Number  Price  \
# 0                                        iPhone 13      MLPH3HN/A  52499
# 1                                              C51      MZB0E6DIN   6499
# 2                                Nord CE 2 Lite 5G    CPH2381/CVD  17196
# 3                                           11x 5G        RMX3785  15999
# 4                                           11x 5G        RMX3785  14999
# ..                                             ...            ...    ...
# 979                                      iPhone 12      MGJC3HN/A  51999
# 980                                         Pova 3            LF7  13999
# 981                                     Note 11 SE      MZB0CK8IN  12890
# 982                                            Y16  V2204 | V2214  10699
# 983  Camon 19 Pro Multi-Colour Changing Back-Panel           CI8n  14940
#
#      Rating No_of_Ratings No_of_Reviews  \
# 0       4.7      259109.0       12745.0
# 1       4.1       78642.0        4449.0
# 2       4.4      110949.0        7728.0
# 3       4.3        2633.0         220.0
# 4       4.4       13807.0         988.0
# ..      ...           ...           ...
# 979     4.6      190693.0       12872.0
# 980     4.1         522.0          24.0
# 981     4.3       47843.0        2894.0
# 982     4.2        2908.0         152.0
# 983     4.1         145.0          13.0
#
#                                             In The Box  ...  \
# 0      iPhone, USB-C to Lightning Cable, Documentation  ...
# 1    Handset, 10W Adapter, USB Cable, Sim Eject Too...  ...
# 2    Phone,SIM Tray Ejector, Adapter, Phone Case, U...  ...
# 3    Handset, Adapter, USB Cable, Important Info Bo...  ...
# 4    Handset, Adapter, USB Cable, Important Info Bo...  ...
# ..                                                 ...  ...
# 979    iPhone, USB-C to Lightning Cable, Documentation  ...
# 980  Handset, USB Cable, Charger, User Guide, SIM E...  ...
# 981  Handset, USB Type-C Cable, Sim Eject Tool, Pro...  ...
# 982  Handset, Documentation, Type-C to USB Cable, U...  ...
# 983  Handset, USB Cable, Charger, User Guide, SIM E...  ...
#
#                                                Sensors        Browser  \
# 0    Face ID, Barometer, Three‑axis Gyro, Accelerom...         Safari
# 1                    Accelerometer, Fingerprint Sensor  Google Chrome
# 2                    Accelerometer, Fingerprint Sensor  Google Chrome
# 3    Magnetic Induction Sensor, Light Sensor, Proxi...      No Detail
# 4    Magnetic Induction Sensor, Light Sensor, Proxi...      No Detail
# ..                                                 ...            ...
# 979  Face ID, Barometer, Three‑axis Gyro, Accelerom...         Safari
# 980  Fingerprint Sensor (side-mounted), G-Sensor, A...  Google Chrome
# 981  Accelerometer, Fingerprint Sensor, Gyro Sensor...  Google Chrome
# 982  Accelerometer, Ambient Light Sensor, Proximity...  Google Chrome
# 983  G-Sensor, Ambient Light and Distance Sensor, F...  Google Chrome
#
#                                         Other Features  \
# 0    Splash, Water and Dust Resistant IP68 Rated (M...
# 1    Splash Resistant Coating, MIUI Dialer, Upto 3 ...
# 2    Splash Resistant Coating, MIUI Dialer, Upto 3 ...
# 3    COG Sealing Process, In-Cell Touch Panel Techn...
# 4    COG Sealing Process, In-Cell Touch Panel Techn...
# ..                                                 ...
# 979  Splash, Water and Dust Resistant (Rated IP68 (...
# 980  Memory Fusion 2.1, 4D Vibration & Z-axis Linea...
# 981                                          No Detail
# 982       10W Fast Charging, Handset Material: Plastic
# 983  13GB RAM (8GB LPDDR4x RAM + Up to 5GB Memory F...
#
#                                             GPS Type  \
# 0    Built-in GPS, GLONASS, Galileo, QZSS and BeiDou
# 1                         GPS, AGPS, GLONASS, BEIDOU
# 2                         GPS, AGPS, GLONASS, BEIDOU
# 3                GPS, AGPS, BEIDOU, GALILEO, GLONASS
# 4                GPS, AGPS, BEIDOU, GALILEO, GLONASS
# ..                                               ...
# 979  Built-in GPS, GLONASS, Galileo, QZSS and BeiDou
# 980                                        No Detail
# 981                       GPS, AGPS, GLONASS, BEIDOU
# 982                    GPS, BEIDOU, GLONASS, GALILEO
# 983                                        No Detail
#
#                                          Video Formats Battery Capacity  \
# 0    HEVC, H.264, MPEG‑4 Part 2 and Motion JPEG, HD...         3240 mAh
# 1                                            No Detail         5000 mAh
# 2                                            No Detail         5000 mAh
# 3    MP4, 3GP, ASF, AVI, FLV, M2TS, MKV, MPG, TS, W...         5000 mAh
# 4    MP4, 3GP, ASF, AVI, FLV, M2TS, MKV, MPG, TS, W...         5000 mAh
# ..                                                 ...              ...
# 979  HEVC, H.264, MPEG‑4 Part 2 and Motion JPEG, HD...         4500 mAh
# 980                                          No Detail         7000 mAh
# 981                                          No Detail         5000 mAh
# 982                        MP4, 3GP, AVI, TS, MKV, FLV         5000 mAh
# 983                        MP4, 3GP, AVI, TS, MKV, FLV         5000 mAh
#
#         Width     Height    Depth     Weight
# 0     71.5 mm   146.7 mm  7.65 mm      173 g
# 1    76.75 mm   164.9 mm  9.09 mm      192 g
# 2    76.75 mm   164.9 mm  9.09 mm      192 g
# 3       76 mm   165.7 mm  7.89 mm      190 g
# 4       76 mm   165.7 mm  7.89 mm      190 g
# ..        ...        ...      ...        ...
# 979   71.5 mm   146.7 mm   7.4 mm      162 g
# 980  78.46 mm   173.1 mm  9.44 mm  No Detail
# 981   74.5 mm  160.46 mm  8.29 mm    178.8 g
# 982  75.55 mm  163.95 mm  8.19 mm      183 g
# 983  74.55 mm  166.79 mm  8.58 mm  No Detail
#
# [984 rows x 72 columns]

# %%
list_of_brands = mobiles["Brand"].unique()
list_of_brands
# Out:
# array(['APPLE', 'POCO', 'OnePlus', 'realme', 'vivo', 'MOTOROLA', 'REDMI',
#        'Infinix', 'Nokia', 'SAMSUNG', 'OPPO', 'Micromax', 'MarQ', 'LAVA',
#        'Google', 'itel', 'Kechaoda', 'HOTLINE', 'Tecno', 'KARBONN', 'I',
#        'GFive', 'DIZO', 'Snexian', 'Good', 'Eunity', 'Energizer', 'IAIR',
#        'Cellecor', 'IQOO', 'Xiaomi', 'MTR', 'Nothing', 'Mi', 'SAREGAMA',
#        'Peace', 'UiSmart', 'Itel'], dtype=object)

# %%
rupeetomyr=0.057 #To see how much the model cost in MYR 
mobiles['PriceMYR'] = mobiles.Price.apply(lambda x : x*rupeetomyr)
mobiles[['Brand','Model Name','Price','PriceMYR']]
# Out:
#        Brand                                     Model Name  Price  PriceMYR
# 0      APPLE                                      iPhone 13  52499  2992.443
# 1       POCO                                            C51   6499   370.443
# 2    OnePlus                              Nord CE 2 Lite 5G  17196   980.172
# 3     realme                                         11x 5G  15999   911.943
# 4     realme                                         11x 5G  14999   854.943
# ..       ...                                            ...    ...       ...
# 979    APPLE                                      iPhone 12  51999  2963.943
# 980    Tecno                                         Pova 3  13999   797.943
# 981    REDMI                                     Note 11 SE  12890   734.730
# 982     vivo                                            Y16  10699   609.843
# 983    Tecno  Camon 19 Pro Multi-Colour Changing Back-Panel  14940   851.580
#
# [984 rows x 4 columns]

# %%
round(mobiles.Price.describe()) #To get more details on price data
# Out:
# count       984.0
# mean      19280.0
# std       26030.0
# min         597.0
# 25%        2098.0
# 50%       11634.0
# 75%       21999.0
# max      199900.0
# Name: Price, dtype: float64

# %%
max_min =  mobiles.iloc[[442, 721], [1,3,5,6,11,30,69,71,72,73]] #Comparison of the most expensive phone and the cheapest phone in the market 
max_min
# Out:
#       Brand         Model Name   Price  Rating     Browse Type  \
# 442   APPLE  Iphone 15 Pro Max  199900     4.8     Smartphones
# 721  Eunity             U1 310     597     3.1  Feature Phones
#
#          Primary Camera Battery Capacity    Height    Depth Weight
# 442  48MP + 12MP + 12MP         4980 mAh  159.9 mm  8.25 mm  221 g
# 721   0.3MP Rear Camera         1000 mAh  147.5 mm  7.85 mm  206 g

# %%
def check_check(browse_type):  #function to check different meaning of the phone type
    phone = {'Smartphones' :'Modern Phone',
                     'Features Phones' : 'Traditional Phone'}
    try : 
        return phone[browse_type]
    except : 
        return 'Not available'
check_check('Features Phones')
# Out:
# 'Traditional Phone'

# %%
iphone12 = mobiles.Price[207]
max_range_of_average_indian_wage = 143000  #Indian wages according to glassdoor website 
min_range_of_average_indian_wage = 8000
average_indian_wage = (max_range_of_average_indian_wage + min_range_of_average_indian_wage)/2
round(average_indian_wage/(iphone12),2) #To find how many month need to save in order to buy Iphone 12
# Out:
# 1.54

# %%
average_malaysian_wage = 3000
Iphone12malaysia = 3099
Iphone12malaysia/average_malaysian_wage #How many month needed for malaysian to save to buy Iphone 12
# Out:
# 1.033

# %%
mobiles[['Brand','Model Name','Price','Rating']].sort_values(by='Price',ascending=False) #Check price
# Out:
#        Brand         Model Name   Price  Rating
# 442    APPLE  Iphone 15 Pro Max  199900     4.8
# 674    APPLE  Iphone 15 Pro Max  179900     4.8
# 809    APPLE  Iphone 15 Pro Max  179900     4.8
# 184    APPLE  Iphone 15 Pro Max  159900     4.8
# 909    APPLE  Iphone 15 Pro Max  159900     4.8
# ..       ...                ...     ...     ...
# 616  Snexian           GURU 312     630     3.3
# 358  Snexian           GURU 312     630     3.3
# 920  Snexian          GURU 2173     630     3.9
# 721   Eunity             U1 310     597     3.1
# 414   Eunity             U1 310     597     3.1
#
# [984 rows x 4 columns]

# %%
mobiles[['Brand','Model Name','Price','Rating']].sort_values(by='Rating',ascending=False) #Check rating
# Out:
#         Brand                                         Model Name   Price  \
# 80    Infinix                                         Smart 7 HD    6199
# 269      POCO                                              X5 5G   16999
# 894  SAREGAMA  Carvaan Mobile Bhakti Don Lite M23 with 351 pr...    1899
# 641     Tecno                                          Pop 7 pro    7199
# 674     APPLE                                  Iphone 15 Pro Max  179900
# ..        ...                                                ...     ...
# 414    Eunity                                             U1 310     597
# 721    Eunity                                             U1 310     597
# 756   HOTLINE                                            CLASSIC     649
# 824   HOTLINE                                            CLASSIC     649
# 908   HOTLINE                                            CLASSIC     649
#
#      Rating
# 80      5.0
# 269     4.9
# 894     4.9
# 641     4.8
# 674     4.8
# ..      ...
# 414     3.1
# 721     3.1
# 756     2.9
# 824     2.9
# 908     2.9
#
# [984 rows x 4 columns]

# %%
revenue_per_brand = mobiles.groupby("Brand")['Price'].sum().sort_values(ascending=False) #revenue per brand 
revenue_per_brand
# Out:
# Brand
# APPLE        7244037
# realme       1579264
# SAMSUNG      1523575
# REDMI        1437776
# OnePlus      1247836
# vivo          977712
# Infinix       903824
# MOTOROLA      897302
# POCO          769034
# OPPO          539266
# Tecno         374929
# Google        263994
# IQOO          259280
# Nothing       185996
# itel          142840
# Xiaomi        140987
# Nokia         108902
# Mi             86478
# Kechaoda       60866
# LAVA           50989
# I              41596
# KARBONN        25303
# Micromax       24825
# Snexian        14891
# SAREGAMA       14349
# Good           10894
# DIZO            7348
# Cellecor        5581
# MTR             5400
# MarQ            5244
# UiSmart         4848
# IAIR            3896
# GFive           3547
# HOTLINE         3243
# Itel            2380
# Energizer       1349
# Eunity          1194
# Peace            749
# Name: Price, dtype: int64

# %%
Mobiles_market = mobiles.groupby("Brand")['Price'].sum().sort_values(ascending=True).tail(10)
Mobiles_market.plot(kind='pie', autopct='%1.1f%%', startangle=90) #mobile market using pie chart 
plt.title ('Mobiles Market')
# Out:
# Text(0.5, 1.0, 'Mobiles Market')

# %%
total = mobiles['Brand'].value_counts().sort_values(ascending=False).head(3) #Check how many sales per brand
total
# Out:
# REDMI     97
# APPLE     88
# realme    88
# Name: Brand, dtype: int64

# %%
quantity_brand = mobiles['Brand'].value_counts().head(10) #pie chart for amount sold per model
ax = quantity_brand.plot(kind='barh')
for i, v in enumerate(quantity_brand):
    ax.text(v, i,str(v)) #put number for each bar 
plt.xlabel('Quantity Sold')
plt.ylabel('Brand')
plt.title('Quantity Sold per Brand')
plt.show()
